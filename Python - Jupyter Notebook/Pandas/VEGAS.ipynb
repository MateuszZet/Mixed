# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random as random
import numpy as np
import pandas as pd

# %%
#v = pd.read_csv('vegascsv.csv')

df1 = pd.read_csv('australia.csv')
df2 = pd.read_csv('izrael.csv')
df3 = pd.read_csv('japonia.csv')
df4 = pd.read_csv('niemcy.csv')
df5 = pd.read_csv('usa.csv')

# %%
#df1['DATE'], df1['TIME'] = df1['mStart'].str.split(' ', 1).str
#df1['DAY'], df1['MONTH'] = df1['DATE'].str.split('.', 1).str

#df1['YEAR'] = df1['MONTH'].str.split('.').str[1]
#df1['MONTH'] = df1['MONTH'].str.split('.').str[0]
#df1['HOUR'] = df1['TIME'].str.split(':').str[0]
#df1['COUNTRY']=1
#df1[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR']]



#df12 = df1.groupby('DATE')['MOR'].mean()
#df13 = df1.groupby('DATE')['MOR'].median()
#df14 = df1.groupby('DATE')['MOR'].std()


#df12.columns = ['MEAN']
#df13.columns = ['MEDIAN']
#df14.columns = ['STD']

#pd.concat(dict(MEAN = df12, MEDIAN = df13, STD = df14),axis=1)#.to_csv('japonia_day.csv')

# %%
#df['DATE'], df['TIME'] = df['mStart'].str.split(' ', 1).str

#df['DAY'], df['MONTH'] = df['DATE'].str.split('.', 1).str

#df[['DATE', 'TIME', 'MOR', 'MONTH']]

#df2 = df.groupby('MONTH')['MOR'].mean()
#df3 = df.groupby('MONTH')['MOR'].median()
#df4 = df.groupby('MONTH')['MOR'].std()


#df2.columns = ['MEAN']
#df3.columns = ['MEDIAN']
#df4.columns = ['STD']

#pd.concat(dict(MEAN = df2, MEDIAN = df3, STD = df4),axis=1).to_csv('nazwa_month.csv')

# %%
df1['DATE'], df1['TIME'] = df1['mStart'].str.split(' ', 1).str
df1['DAY'], df1['MONTH'] = df1['DATE'].str.split('.', 1).str

df1['YEAR'] = df1['MONTH'].str.split('.').str[1]
df1['MONTH'] = df1['MONTH'].str.split('.').str[0]
df1['HOUR'] = df1['TIME'].str.split(':').str[0]
df1['MIN'] = df1['TIME'].str.split(':').str[1]
df1['COUNTRY']=1
df1[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']]
# Out:
#       COUNTRY HOUR DAY MONTH  YEAR      MOR     LAST
# 0           1   00  29    10  2008  1511082  1131517
# 1           1   01  29    10  2008  1520726  1139927
# 2           1   01  29    10  2008  1517191  1137984
# 3           1   02  29    10  2008  1515324  1132833
# 4           1   02  29    10  2008  1514437  1133126
# 5           1   03  29    10  2008  1523084  1143340
# 6           1   03  29    10  2008  1517774  1138203
# 7           1   04  29    10  2008  1510992  1132591
# 8           1   04  29    10  2008  1512010  1133051
# 9           1   05  29    10  2008  1509593  1131421
# 10          1   05  29    10  2008  1510222  1131929
# 11          1   06  29    10  2008  1516162  1135745
# 12          1   06  29    10  2008  1511187  1131823
# 13          1   07  29    10  2008  1509993  1131317
# 14          1   07  29    10  2008  1509198  1131161
# 15          1   08  29    10  2008  1510929  1132664
# 16          1   08  29    10  2008  1510302  1131954
# ...

# %%
df2['DATE'], df2['TIME'] = df2['mStart'].str.split(' ', 1).str
df2['DAY'], df2['MONTH'] = df2['DATE'].str.split('.', 1).str

df2['YEAR'] = df2['MONTH'].str.split('.').str[1]
df2['MONTH'] = df2['MONTH'].str.split('.').str[0]
df2['HOUR'] = df2['TIME'].str.split(':').str[0]
df2['MIN'] = df2['TIME'].str.split(':').str[1]
df2['COUNTRY']=2
df2[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']]
# Out:
#        COUNTRY HOUR DAY MONTH  YEAR      MOR     LAST
# 0            2   00  29    10  2008  2774988  1501388
# 1            2   00  29    10  2008  2016866  1503679
# 2            2   01  29    10  2008  2047526  1504890
# 3            2   01  29    10  2008  2038797  1501829
# 4            2   02  29    10  2008  2015799  1503803
# 5            2   02  29    10  2008  2018313  1503564
# 6            2   03  29    10  2008  2287727  1503352
# 7            2   03  29    10  2008  2017729  1503816
# 8            2   04  29    10  2008  2155918  1503373
# 9            2   04  29    10  2008  2014411  1503360
# 10           2   05  29    10  2008  2061565  1503661
# 11           2   05  29    10  2008  2038173  1503519
# 12           2   06  29    10  2008  2013619  1503193
# 13           2   06  29    10  2008  2013105  1502602
# 14           2   07  29    10  2008  2012349  1501889
# 15           2   07  29    10  2008  2015422  1503430
# ...

# %%
df3['DATE'], df3['TIME'] = df3['mStart'].str.split(' ', 1).str
df3['DAY'], df3['MONTH'] = df3['DATE'].str.split('.', 1).str

df3['YEAR'] = df3['MONTH'].str.split('.').str[1]
df3['MONTH'] = df3['MONTH'].str.split('.').str[0]
df3['HOUR'] = df3['TIME'].str.split(':').str[0]
df3['COUNTRY']=3
df3['MIN'] = df3['TIME'].str.split(':').str[1]
df3[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']]
# Out:
#        COUNTRY HOUR DAY MONTH  YEAR       MOR     LAST
# 0            3   00  29    10  2008  11499073   763335
# 1            3   00  29    10  2008   1196793   761671
# 2            3   01  29    10  2008   1199030   765135
# 3            3   01  29    10  2008   1250017   781200
# 4            3   02  29    10  2008   1276172   765964
# 5            3   02  29    10  2008   1580663  1140065
# 6            3   03  29    10  2008   1203884   763055
# 7            3   03  29    10  2008   1202932   769601
# 8            3   04  29    10  2008   3257173  2385096
# 9            3   04  29    10  2008   1735283  1399749
# 10           3   05  29    10  2008   1073296   773909
# 11           3   05  29    10  2008   1189234   880846
# 12           3   06  29    10  2008   1080908   770826
# 13           3   06  29    10  2008   1204505   891353
# 14           3   07  29    10  2008   1951395  1646090
# 15           3   07  29    10  2008   1079213   763203
# ...

# %%
df4['DATE'], df4['TIME'] = df4['mStart'].str.split(' ', 1).str
df4['DAY'], df4['MONTH'] = df4['DATE'].str.split('.', 1).str

df4['YEAR'] = df4['MONTH'].str.split('.').str[1]
df4['MONTH'] = df4['MONTH'].str.split('.').str[0]
df4['HOUR'] = df4['TIME'].str.split(':').str[0]
df4['COUNTRY']=4
df4['MIN'] = df4['TIME'].str.split(':').str[1]
df4[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']]
# Out:
#        COUNTRY HOUR DAY MONTH  YEAR      MOR     LAST
# 0            4   00  29    10  2008  1665250  1237636
# 1            4   01  29    10  2008  1651332  1236871
# 2            4   01  29    10  2008  1676860  1237705
# 3            4   02  29    10  2008  1653133  1238244
# 4            4   02  29    10  2008  1666564  1237296
# 5            4   03  29    10  2008  1868657  1237823
# 6            4   03  29    10  2008  1652769  1238017
# 7            4   04  29    10  2008  1649917  1236422
# 8            4   04  29    10  2008  1652131  1237715
# 9            4   05  29    10  2008  1650375  1237052
# 10           4   05  29    10  2008  1650680  1237364
# 11           4   06  29    10  2008  1650484  1237284
# 12           4   06  29    10  2008  1650618  1237488
# 13           4   07  29    10  2008  1786637  1237008
# 14           4   07  29    10  2008  1674918  1238551
# 15           4   08  29    10  2008  1651475  1237851
# ...

# %%
df5['DATE'], df5['TIME'] = df5['mStart'].str.split(' ', 1).str
df5['DAY'], df5['MONTH'] = df5['DATE'].str.split('.', 1).str

df5['YEAR'] = df5['MONTH'].str.split('.').str[1]
df5['MONTH'] = df5['MONTH'].str.split('.').str[0]
df5['HOUR'] = df5['TIME'].str.split(':').str[0]
df5['COUNTRY']=5
df5['MIN'] = df5['TIME'].str.split(':').str[1]
df5[['COUNTRY', 'HOUR', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']]
# Out:
#       COUNTRY HOUR DAY MONTH  YEAR      MOR    LAST
# 0           5   00  29    10  2008   256557  166580
# 1           5   00  29    10  2008   269193  166895
# 2           5   01  29    10  2008   268689  166860
# 3           5   01  29    10  2008   254743  166853
# 4           5   02  29    10  2008   273042  166545
# 5           5   02  29    10  2008   272090  166778
# 6           5   03  29    10  2008   290049  166334
# 7           5   03  29    10  2008   259165  166667
# 8           5   04  29    10  2008   255401  166419
# 9           5   04  29    10  2008   326536  166704
# 10          5   05  29    10  2008   251934  166539
# 11          5   05  29    10  2008   277898  166778
# 12          5   06  29    10  2008   256231  166821
# 13          5   06  29    10  2008   295177  166618
# 14          5   07  29    10  2008   272478  166618
# 15          5   07  29    10  2008   274613  166955
# 16          5   08  29    10  2008   397968  166579
# ...

# %%
frames = [df1, df2, df3, df4, df5]
result = pd.concat(frames,ignore_index=True)

# %%
result[['COUNTRY', 'HOUR', 'MIN', 'DAY', 'MONTH','YEAR', 'MOR', 'LAST']].to_csv('podzial2.csv')
